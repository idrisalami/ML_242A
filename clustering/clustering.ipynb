# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import ast

df = pd.read_csv('founders_dataset.csv')
print(f"Dataset shape: {df.shape}")
df.head()
# Out:
# Dataset shape: (1209, 25)
#      roles preferred_role  ... communication execution_speed
# 0  ["COO"]            COO  ...             3               4
# 1  ["CEO"]            CEO  ...             5               5
# 2  ["CEO"]            CEO  ...             5               3
# 3  ["COO"]            COO  ...             4               5
# 4  ["CTO"]            CTO  ...             4               3
#
# [5 rows x 25 columns]

# %% [markdown]
# ## **Data preprocessing**
#
# Before clustering, we need to convert all features into numerical format. This involves:
#
# 1. **Multi-label encoding**: Convert list-like columns (roles, tech_stack, etc.) to binary features
# 2. **Categorical encoding**: One-hot encode single-value categorical features
# 3. **Numeric scaling**: Standardize numerical features

# %%
# Define column types
multi_label_cols = [
    'roles',
    'secondary_industries', 
    'tech_stack',
    'strengths',
    'weaknesses'
]

text_cols = [
    'idea_title',
    'idea_description', 
    'problem_space'
]

categorical_cols = [
    'preferred_role',
    'industry',
    'education_level',
    'gender',
    'is_technical'
]

numeric_cols = [
    'years_of_experience',
    'age',
    'collaboration_openness_score',
    'communication_intensity_score',
    'responsiveness_score',
    'risk_tolerance',
    'leadership',
    'autonomy',
    'vision',
    'communication',
    'execution_speed'
]

# %% [markdown]
# Convert string representations of lists into actual Python lists for processing.

# %%
# Convert list-like strings to actual lists
for col in multi_label_cols:
    df[col] = df[col].fillna('[]').apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Display sample of parsed data
print("Sample of parsed multi-label columns:")
df[multi_label_cols].head(3)
# Out:
# Sample of parsed multi-label columns:
#    roles  ...                                         weaknesses
# 0  [COO]  ...       [Risk-averse, Impatient with slow processes]
# 1  [CEO]  ...  [Poor work-life balance, Limited business expe...
# 2  [CEO]  ...            [Overly detail-oriented, Weak in sales]
#
# [3 rows x 5 columns]

# %% [markdown]
# Convert multi-label columns into binary feature vectors using MultiLabelBinarizer.

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# Process each multi-label column
mlb_features = {}
for col in multi_label_cols:
    mlb = MultiLabelBinarizer()
    mlb_features[col] = mlb.fit_transform(df[col])
    print(f"{col}: {mlb_features[col].shape[1]} unique values")

# Show total binary features created
total_mlb_features = sum(feat.shape[1] for feat in mlb_features.values())
print(f"Total multi-label binary features: {total_mlb_features}")
# Out:
# roles: 4 unique values
# secondary_industries: 1 unique values
# tech_stack: 75 unique values
# strengths: 14 unique values
# weaknesses: 14 unique values
# Total multi-label binary features: 108

# %% [markdown]
# Use scikit-learn's ColumnTransformer to process categorical and numeric features together.

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

# Create preprocessing pipeline
preprocess = ColumnTransformer(
    transformers=[
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_cols),
        ("num", StandardScaler(), numeric_cols),
    ]
)

# Fit and transform the structured features
X_structured = preprocess.fit_transform(df)

print(f"Structured features shape: {X_structured.shape}")
# Out:
# Structured features shape: (1209, 37)

# %% [markdown]
# Merge all feature types into a single feature matrix for clustering.

# %%
# Combine all features: structured + multi-label (no text embeddings)
X = np.hstack([
    X_structured,
    *[mlb_features[col] for col in multi_label_cols]
])

print(f"Final feature matrix shape: {X.shape}")
print(f"Total features per founder: {X.shape[1]}")
# Out:
# Final feature matrix shape: (1209, 145)
# Total features per founder: 145

# %% [markdown]
# ## **Dimensionality reduction with PCA**
#
# Since we have many features, we'll use Principal Component Analysis (PCA) to reduce dimensionality while retaining most of the variance. This helps:
# - Speed up clustering algorithms
# - Reduce noise in the data
# - Avoid curse of dimensionality

# %% [markdown]
# ## **Complementarity clustering**
#
# We will produce a complementarity-based clustering (group complementary founders together using graph-based affinity)

# %%
from sklearn.decomposition import PCA

# Apply PCA to reduce dimensions
n_components = 70
pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(X)

# Show variance explained
cumulative_variance = np.cumsum(pca.explained_variance_ratio_)

# Plot variance explained
plt.figure(figsize=(10, 5))
plt.plot(range(1, n_components + 1), cumulative_variance, marker='o')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('PCA Variance Explained')
plt.grid(True)
plt.show()

print(f"Reduced feature matrix shape: {X_pca.shape}")

# choose optimal number of PCA components based on variance explained plot >= 0.9
n_components = cumulative_variance.searchsorted(0.9) + 1
print(f"Optimal number of PCA components for 90% variance: {n_components}")

pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(X)
# Out:
# Reduced feature matrix shape: (1209, 70)
# Optimal number of PCA components for 90% variance: 53

# %% [markdown]
# # KMeans clustering

# %% [markdown]
# Before clustering, we construct a complementarity affinity matrix based on role differences, tech diversity, and strengths-weaknesses coverage.

# %%
import numpy as np
import pandas as pd

def jaccard_similarity(list_a, list_b):
    a = set(list_a or [])
    b = set(list_b or [])
    if not a and not b:
        return 1.0
    return len(a & b) / len(a | b)

def jaccard_diversity(list_a, list_b):
    return 1.0 - jaccard_similarity(list_a, list_b)

def strengths_weaknesses_complement(s_a, w_a, s_b, w_b):
    s_a, w_a = set(s_a or []), set(w_a or [])
    s_b, w_b = set(s_b or []), set(w_b or [])
    a_covers = len(s_a & w_b)
    b_covers = len(s_b & w_a)
    max_possible = max(1, len(w_a) + len(w_b))
    return (a_covers + b_covers) / max_possible


def build_complementarity_matrix(df):
    n = len(df)
    comp_aff = np.zeros((n, n), dtype=float)

    for i in range(n):
        for j in range(i + 1, n):
            role_diff = float(df['preferred_role'].iloc[i] != df['preferred_role'].iloc[j])
            roles_div = jaccard_diversity(df['roles'].iloc[i], df['roles'].iloc[j])
            tech_div = jaccard_diversity(df['tech_stack'].iloc[i], df['tech_stack'].iloc[j])
            sw_comp = strengths_weaknesses_complement(
                df['strengths'].iloc[i], df['weaknesses'].iloc[i],
                df['strengths'].iloc[j], df['weaknesses'].iloc[j]
            )
            score = 0.35 * role_diff + 0.30 * roles_div + 0.20 * tech_div + 0.15 * sw_comp
            comp_aff[i, j] = comp_aff[j, i] = score

    return comp_aff

comp_affinity = build_complementarity_matrix(df)
print(f"Complementarity affinity matrix shape: {comp_affinity.shape}")
# Out:
# Complementarity affinity matrix shape: (1209, 1209)

# %% [markdown]
# ## **KMeans**

# %% [markdown]
# Determine optimal number of clusters with elbow method

# %%
from sklearn.cluster import KMeans

k_range = range(2, 11)
kmeans_models = {}
for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_pca)
    kmeans_models[k] = kmeans
    print(f"K={k}, Inertia: {kmeans.inertia_}")

plt.figure(figsize=(10, 5))
inertias = [kmeans_models[k].inertia_ for k in k_range]
plt.plot(k_range, inertias, marker='o')
plt.xlabel('Number of Clusters K')
plt.ylabel('Inertia')
plt.title('K-Means Inertia vs. Number of Clusters')
plt.grid(True)
# Out:
# K=2, Inertia: 22501.683009037075
# K=3, Inertia: 21397.91472202024
# K=4, Inertia: 20752.39934388506
# K=5, Inertia: 20079.334325344877
# K=6, Inertia: 19609.65792347169
# K=7, Inertia: 19430.08339778683
# K=8, Inertia: 18943.12152316142
# K=9, Inertia: 18743.729677109557
# K=10, Inertia: 18279.738261837367

# %%
n_clusters = 6

kmeans = KMeans(n_clusters=n_clusters, random_state=42)
clusters_comp = kmeans.fit_predict(X_pca)

# Add labels
df['cluster_complementarity'] = clusters_comp
print("KMeans-based cluster sizes:")
print(df['cluster_complementarity'].value_counts().sort_index())
# Out:
# KMeans-based cluster sizes:
# cluster_complementarity
# 0     27
# 1    295
# 2    315
# 3    241
# 4    175
# 5    156
# Name: count, dtype: int64

# %% [markdown]
# We compute a pairwise complementarity score between founders (role difference, tech diversity, and strengths covering weaknesses) and summarize within-cluster complementarity for KMeans clustering.

# %%
def cluster_complementarity_summary(labels, comp_aff):
    labels = np.asarray(labels)
    cluster_ids = sorted(set(labels))
    results = []
    total_pairs = 0
    total_sum = 0.0
    for cid in cluster_ids:
        idx = np.where(labels == cid)[0]
        if len(idx) < 2:
            mean_comp = float('nan')
            pair_count = 0
        else:
            sub = comp_aff[np.ix_(idx, idx)]
            tri = sub[np.triu_indices_from(sub, k=1)]
            pair_count = len(tri)
            mean_comp = float(tri.mean()) if pair_count > 0 else float('nan')
        results.append((cid, len(idx), pair_count, mean_comp))
        if pair_count > 0 and not np.isnan(mean_comp):
            total_pairs += pair_count
            total_sum += tri.sum()
    overall_mean = (total_sum / total_pairs) if total_pairs > 0 else float('nan')
    return results, overall_mean

# Evaluate KMeans clustering complementarity
kmeans_results, kmeans_overall = cluster_complementarity_summary(df['cluster_complementarity'], comp_affinity)
print("KMeans Clustering Complementarity (within clusters):")
for cid, size, pairs, mean_comp in kmeans_results:
    print(f"Cluster {cid}: size={size}, pairs={pairs}, mean_comp={mean_comp:.3f}")
print(f"Overall (pair-weighted) mean complementarity: {kmeans_overall:.3f}")
# Out:
# KMeans Clustering Complementarity (within clusters):
# Cluster 0: size=27, pairs=351, mean_comp=0.675
# Cluster 1: size=295, pairs=43365, mean_comp=0.626
# Cluster 2: size=315, pairs=49455, mean_comp=0.613
# Cluster 3: size=241, pairs=28920, mean_comp=0.642
# Cluster 4: size=175, pairs=15225, mean_comp=0.653
# Cluster 5: size=156, pairs=12090, mean_comp=0.638
# Overall (pair-weighted) mean complementarity: 0.629

# %%
# Analyze numeric features by complementarity cluster
numeric_analysis = df.groupby('cluster_complementarity')[numeric_cols].mean()
print("Average numeric features by complementarity cluster:")
print(numeric_analysis.round(2))
# Out:
# Average numeric features by complementarity cluster:
#                          years_of_experience  ...  execution_speed
# cluster_complementarity                       ...
# 0                                       4.52  ...             3.33
# 1                                       3.93  ...             3.59
# 2                                       3.61  ...             3.58
# 3                                       4.25  ...             3.56
# 4                                       9.03  ...             3.62
# 5                                       4.50  ...             3.35
#
# [6 rows x 11 columns]

# %%
# Analyze categorical features by complementarity clusters
print("CLUSTER PROFILES - CATEGORICAL FEATURES (Complementarity)")

for cluster_id in sorted(df['cluster_complementarity'].unique()):
    cluster_data = df[df['cluster_complementarity'] == cluster_id]
    print(f"CLUSTER {cluster_id} (n={len(cluster_data)} founders)")
    
    # Most common categorical values
    print("Preferred Roles:")
    print(cluster_data['preferred_role'].value_counts().head())
    
    print("Industries:")
    print(cluster_data['industry'].value_counts().head())
    
    print("Education Levels:")
    print(cluster_data['education_level'].value_counts().head())
    
    print("Gender Distribution:")
    print(cluster_data['gender'].value_counts())

    print("="*80)
# Out:
# CLUSTER PROFILES - CATEGORICAL FEATURES (Complementarity)
# CLUSTER 0 (n=27 founders)
# Preferred Roles:
# preferred_role
# CTO    9
# CEO    8
# COO    5
# CPO    5
# Name: count, dtype: int64
# Industries:
# industry
# Marketplaces           4
# E-commerce             3
# Climate / Greentech    3
# Edtech                 3
# Healthtech             2
# Name: count, dtype: int64
# Education Levels:
# education_level
# bachelor       10
# bootcamp        7
# master          5
# self-taught     5
# Name: count, dtype: int64
# Gender Distribution:
# gender
# M    23
# F     4
# Name: count, dtype: int64
# ================================================================================
# CLUSTER 1 (n=295 founders)
# Preferred Roles:
# preferred_role
# CEO    145
# CTO     63
# CPO     47
# COO     40
# Name: count, dtype: int64
# Industries:
# industry
# AI / Deeptech        33
# Marketplaces         29
# Consumer / Social    29
# Web3 / Crypto        24
# SaaS                 23
# Name: count, dtype: int64
# Education Levels:
# education_level
# bachelor       96
# bootcamp       73
# self-taught    58
# master         56
# phd            12
# Name: count, dtype: int64
# Gender Distribution:
# gender
# M    263
# F     32
# Name: count, dtype: int64
# ================================================================================
# CLUSTER 2 (n=315 founders)
# Preferred Roles:
# preferred_role
# CTO    148
# CEO     90
# CPO     41
# COO     36
# Name: count, dtype: int64
# Industries:
# industry
# AI / Deeptech             35
# Gaming / Entertainment    32
# Fintech                   30
# Climate / Greentech       30
# E-commerce                29
# Name: count, dtype: int64
# Education Levels:
# education_level
# bachelor       129
# self-taught     67
# bootcamp        55
# master          48
# phd             16
# Name: count, dtype: int64
# Gender Distribution:
# gender
# M    266
# F     49
# Name: count, dtype: int64
# ================================================================================
# CLUSTER 3 (n=241 founders)
# Preferred Roles:
# preferred_role
# CEO    102
# CTO     64
# COO     40
# CPO     35
# Name: count, dtype: int64
# Industries:
# industry
# Marketplaces           28
# E-commerce             22
# Climate / Greentech    22
# Fintech                22
# Edtech                 21
# Name: count, dtype: int64
# Education Levels:
# education_level
# bachelor       68
# bootcamp       60
# master         59
# self-taught    40
# phd            14
# Name: count, dtype: int64
# Gender Distribution:
# gender
# M    205
# F     36
# Name: count, dtype: int64
# ================================================================================
# CLUSTER 4 (n=175 founders)
# Preferred Roles:
# preferred_role
# CTO    61
# CEO    54
# CPO    32
# COO    28
# Name: count, dtype: int64
# Industries:
# industry
# Biotech                   22
# Healthtech                16
# Marketplaces              16
# E-commerce                15
# Gaming / Entertainment    15
# Name: count, dtype: int64
# Education Levels:
# education_level
# master         58
# bachelor       37
# bootcamp       36
# self-taught    32
# phd            12
# Name: count, dtype: int64
# Gender Distribution:
# gender
# M    157
# F     18
# Name: count, dtype: int64
# ================================================================================
# CLUSTER 5 (n=156 founders)
# Preferred Roles:
# preferred_role
# CTO    61
# CEO    52
# COO    25
# CPO    18
# Name: count, dtype: int64
# Industries:
# industry
# Gaming / Entertainment    16
# Other                     14
# Edtech                    13
# Web3 / Crypto             13
# Biotech                   13
# Name: count, dtype: int64
# Education Levels:
# education_level
# bachelor       56
# self-taught    40
# master         36
# bootcamp       20
# phd             4
# Name: count, dtype: int64
# Gender Distribution:
# gender
# M    145
# F     11
# Name: count, dtype: int64
# ================================================================================

# %%
# Analyze multi-label features (most common values in each cluster)
print("CLUSTER PROFILES - MULTI-LABEL FEATURES")

for cluster_id in sorted(df['cluster_complementarity'].unique()):
    cluster_data = df[df['cluster_complementarity'] == cluster_id]
    print(f"CLUSTER {cluster_id}")
    
    # Flatten lists and count occurrences
    for col in ['roles', 'tech_stack', 'strengths', 'weaknesses']:
        all_values = [item for sublist in cluster_data[col] for item in sublist]
        if all_values:
            value_counts = pd.Series(all_values).value_counts().head(5)
            print(f"Top {col}:")
            print(value_counts)

    print(f"{'='*80}")
# Out:
# CLUSTER PROFILES - MULTI-LABEL FEATURES
# CLUSTER 0
# Top roles:
# CTO    9
# CEO    8
# COO    7
# CPO    7
# Name: count, dtype: int64
# Top tech_stack:
# Python     11
# Webflow     7
# Figma       6
# Docker      5
# Swift       5
# Name: count, dtype: int64
# Top strengths:
# Creativity and vision    15
# Scrappiness              11
# Team-building             8
# User empathy              7
# Strategic thinking        7
# Name: count, dtype: int64
# Top weaknesses:
# Difficulty delegating            7
# Impatient with slow processes    7
# Lack of focus                    5
# Limited technical experience     5
# Struggles with prioritization    4
# Name: count, dtype: int64
# ================================================================================
# CLUSTER 1
# Top roles:
# CEO    146
# CTO     84
# CPO     75
# COO     48
# Name: count, dtype: int64
# Top tech_stack:
# Python        89
# React         73
# Node.js       69
# AWS           63
# PostgreSQL    54
# Name: count, dtype: int64
# Top strengths:
# Creativity and vision    88
# User empathy             82
# Strong leadership        79
# Scrappiness              65
# High ownership           64
# Name: count, dtype: int64
# Top weaknesses:
# Overly perfectionist              52
# Poor work-life balance            51
# Difficulty delegating             51
# Risk-averse                       49
# Easily distracted by new ideas    48
# Name: count, dtype: int64
# ================================================================================
# CLUSTER 2
# Top roles:
# CTO    161
# CEO     90
# CPO     55
# COO     44
# Name: count, dtype: int64
# Top tech_stack:
# Python        99
# React         96
# Node.js       94
# AWS           68
# PostgreSQL    52
# Name: count, dtype: int64
# Top strengths:
# Creativity and vision       123
# User empathy                 92
# Ability to learn quickly     75
# Technical depth              72
# Scrappiness                  71
# Name: count, dtype: int64
# Top weaknesses:
# Limited business experience      61
# Impatient with slow processes    57
# Weak in hiring                   54
# Difficulty delegating            47
# Overly detail-oriented           46
# Name: count, dtype: int64
# ================================================================================
# CLUSTER 3
# Top roles:
# CEO    102
# CTO     74
# CPO     49
# COO     44
# Name: count, dtype: int64
# Top tech_stack:
# Python      76
# React       47
# Firebase    44
# Figma       43
# AWS         42
# Name: count, dtype: int64
# Top strengths:
# Creativity and vision       71
# Strong leadership           60
# Ability to learn quickly    60
# User empathy                57
# Team-building               56
# Name: count, dtype: int64
# Top weaknesses:
# Impatient with slow processes     41
# Overly perfectionist              41
# Overly optimistic                 40
# Easily distracted by new ideas    38
# Struggles with prioritization     36
# Name: count, dtype: int64
# ================================================================================
# CLUSTER 4
# Top roles:
# CTO    68
# CEO    56
# CPO    47
# COO    35
# Name: count, dtype: int64
# Top tech_stack:
# AWS       39
# React     39
# Python    39
# Notion    38
# Swift     35
# Name: count, dtype: int64
# Top strengths:
# Scrappiness                   45
# User empathy                  44
# Strong leadership             42
# Creativity and vision         42
# Analytical problem-solving    40
# Name: count, dtype: int64
# Top weaknesses:
# Difficulty delegating          31
# Risk-averse                    28
# Weak in sales                  28
# Weak in hiring                 28
# Limited business experience    27
# Name: count, dtype: int64
# ================================================================================
# CLUSTER 5
# Top roles:
# CTO    66
# CEO    52
# COO    31
# CPO    27
# Name: count, dtype: int64
# Top tech_stack:
# Python        46
# Node.js       37
# PostgreSQL    34
# Firebase      32
# React         31
# Name: count, dtype: int64
# Top strengths:
# Strong leadership        46
# Creativity and vision    44
# User empathy             43
# Scrappiness              39
# High ownership           38
# Name: count, dtype: int64
# Top weaknesses:
# Limited business experience      31
# Overly detail-oriented           29
# Struggles with prioritization    26
# Difficulty delegating            25
# Overly perfectionist             22
# Name: count, dtype: int64
# ================================================================================

# %% [markdown]
# ## **Complementarity evaluation**

# %%
def top_complementary_pairs(labels, comp_aff, top_n=5):
    labels = np.asarray(labels)
    results = {}
    for cid in sorted(set(labels)):
        idx = np.where(labels == cid)[0]
        pairs = []
        if len(idx) >= 2:
            sub = comp_aff[np.ix_(idx, idx)]
            for a in range(len(idx)):
                for b in range(a+1, len(idx)):
                    i, j = idx[a], idx[b]
                    pairs.append((i, j, sub[a, b]))
            pairs.sort(key=lambda x: x[2], reverse=True)
            results[cid] = pairs[:top_n]
        else:
            results[cid] = []
    return results

def print_pair_examples(title, pairs_dict):
    print(f"{title}")
    for cid in sorted(pairs_dict.keys()):
        print(f"Cluster {cid} - Top Complementary Pairs")
        cluster_pairs = pairs_dict[cid]
        if not cluster_pairs:
            print("No pairs available (cluster size < 2)")
            continue
        for (i, j, score) in cluster_pairs:
            row_i = df.iloc[i]
            row_j = df.iloc[j]
            role_i = row_i['preferred_role']
            role_j = row_j['preferred_role']
            tech_i = row_i['tech_stack'] or []
            tech_j = row_j['tech_stack'] or []
            strengths_i = row_i['strengths'] or []
            strengths_j = row_j['strengths'] or []
            weaknesses_i = row_i['weaknesses'] or []
            weaknesses_j = row_j['weaknesses'] or []
            role_diff = 1.0 if role_i != role_j else 0.0
            tech_diversity = 1 - jaccard_similarity(tech_i, tech_j)
            sw_comp = strengths_weaknesses_complement(strengths_i, weaknesses_i, strengths_j, weaknesses_j)
            print(f"Pair: Founder {row_i['founder_id']} ↔ Founder {row_j['founder_id']}")
            print(f"  Complementarity Score: {score:.3f} | RoleDiff: {role_diff:.1f} | TechDiv: {tech_diversity:.2f} | S↔W: {sw_comp:.2f}")
            print(f"  Roles: {role_i} ↔ {role_j}")
            print(f"  Tech (samples): {', '.join(tech_i[:3]) if tech_i else 'None'} ↔ {', '.join(tech_j[:3]) if tech_j else 'None'}")
            print(f"  Strengths (samples): {', '.join(strengths_i[:2]) if strengths_i else 'None'} ↔ {', '.join(strengths_j[:2]) if strengths_j else 'None'}")

    print(f"{'='*80}")

# %%
# Top pairs for KMeans clusters
pairs_kmeans = top_complementary_pairs(clusters_comp, comp_affinity, top_n=5)
print_pair_examples("KMeans - Top Complementary Pairs", pairs_kmeans)
# Out:
# Spectral - Top Complementary Pairs
# Cluster 0 - Top Complementary Pairs
# Pair: Founder 53f6bdb7eeb0c0eedf8dbf5c271ff887 ↔ Founder cef50ce50692bb1260ae383c8e2a029c
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: CTO ↔ CEO
#   Tech (samples): MongoDB, PostgreSQL, AWS ↔ Figma, Slack, Trello
#   Strengths (samples): Creativity and vision, Ability to learn quickly ↔ Strong leadership, User empathy
# Pair: Founder 53f6bdb7eeb0c0eedf8dbf5c271ff887 ↔ Founder 160dae1bf017f6109584bc5d11595428
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: CTO ↔ COO
#   Tech (samples): MongoDB, PostgreSQL, AWS ↔ Excel, Google Analytics
#   Strengths (samples): Creativity and vision, Ability to learn quickly ↔ Strong leadership, Creativity and vision
# Pair: Founder 53f6bdb7eeb0c0eedf8dbf5c271ff887 ↔ Founder 2f051007e7936f333b5a19bab9f9d5c4
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: CTO ↔ CPO
#   Tech (samples): MongoDB, PostgreSQL, AWS ↔ Excel, Figma, Notion
#   Strengths (samples): Creativity and vision, Ability to learn quickly ↔ Creativity and vision, Communication skills
# Pair: Founder 53f6bdb7eeb0c0eedf8dbf5c271ff887 ↔ Founder 3c159947bd2b43b5983d9e5b01b136be
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: CTO ↔ CPO
#   Tech (samples): MongoDB, PostgreSQL, AWS ↔ Django, Webflow
#   Strengths (samples): Creativity and vision, Ability to learn quickly ↔ Creativity and vision, High ownership
# Pair: Founder 53f6bdb7eeb0c0eedf8dbf5c271ff887 ↔ Founder e5b8586a4a9b0315bbbf2b8df0e87ded
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: CTO ↔ CPO
#   Tech (samples): MongoDB, PostgreSQL, AWS ↔ Docker, Figma, React
#   Strengths (samples): Creativity and vision, Ability to learn quickly ↔ Scrappiness, High ownership
# Cluster 1 - Top Complementary Pairs
# Pair: Founder 048dd37565ad9cbc24c163ffedffbf58 ↔ Founder dcbbdea918ea83820eef63a0f07bbfb2
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: CEO ↔ COO
#   Tech (samples): React, Node.js, Firebase ↔ Bubble, AWS
#   Strengths (samples): Creativity and vision, High ownership ↔ Scrappiness, Ability to learn quickly
# Pair: Founder 048dd37565ad9cbc24c163ffedffbf58 ↔ Founder 2db8f3512addaf8fa83df76ad09d931e
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: CEO ↔ COO
#   Tech (samples): React, Node.js, Firebase ↔ Bubble, Swift, Kubernetes
#   Strengths (samples): Creativity and vision, High ownership ↔ High ownership, Technical depth
# Pair: Founder 048dd37565ad9cbc24c163ffedffbf58 ↔ Founder 405e109c8904421b0c98955f31a04d46
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: CEO ↔ CPO
#   Tech (samples): React, Node.js, Firebase ↔ MongoDB, Python
#   Strengths (samples): Creativity and vision, High ownership ↔ User empathy, Communication skills
# Pair: Founder 048dd37565ad9cbc24c163ffedffbf58 ↔ Founder 48577c92e4c59d8603d6cdc4fe04f221
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: CEO ↔ CTO
#   Tech (samples): React, Node.js, Firebase ↔ Django, Kubernetes, Webflow
#   Strengths (samples): Creativity and vision, High ownership ↔ Ability to learn quickly, Technical depth
# Pair: Founder 048dd37565ad9cbc24c163ffedffbf58 ↔ Founder 72983c8b1a776df2254aae4009f163c3
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: CEO ↔ COO
#   Tech (samples): React, Node.js, Firebase ↔ Excel, Notion, Docker
#   Strengths (samples): Creativity and vision, High ownership ↔ Strategic thinking, User empathy
# Cluster 2 - Top Complementary Pairs
# Pair: Founder 10a8c197447a3991d64136b315d6e87e ↔ Founder 1f4873925d958cab973bc21385bc956e
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: CEO ↔ CTO
#   Tech (samples): Unity, C#, JavaScript ↔ Kubernetes, Firebase, Python
#   Strengths (samples): User empathy, Team-building ↔ Strategic thinking, High ownership
# Pair: Founder 10a8c197447a3991d64136b315d6e87e ↔ Founder 51fc9e218bb9785ef8a6814e282cf8d8
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: CEO ↔ CPO
#   Tech (samples): Unity, C#, JavaScript ↔ React, Node.js, AWS
#   Strengths (samples): User empathy, Team-building ↔ User empathy, Ability to learn quickly
# Pair: Founder 10a8c197447a3991d64136b315d6e87e ↔ Founder 72bbe06cfd45e7607593a2b21038eccc
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: CEO ↔ CTO
#   Tech (samples): Unity, C#, JavaScript ↔ React, Node.js, AWS
#   Strengths (samples): User empathy, Team-building ↔ Resilience, Team-building
# Pair: Founder 10a8c197447a3991d64136b315d6e87e ↔ Founder 7e29bf29d8ef02ecd97bdc5cf250b2a5
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: CEO ↔ CTO
#   Tech (samples): Unity, C#, JavaScript ↔ Node.js, React, Docker
#   Strengths (samples): User empathy, Team-building ↔ User empathy, Strong leadership
# Pair: Founder 10a8c197447a3991d64136b315d6e87e ↔ Founder 98dbfdbe60e16880422a8a0a9328580b
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: CEO ↔ CTO
#   Tech (samples): Unity, C#, JavaScript ↔ Python, Django, AWS
#   Strengths (samples): User empathy, Team-building ↔ Technical depth, Ability to learn quickly
# Cluster 3 - Top Complementary Pairs
# Pair: Founder 0a5e3dd8489fe67485ddb7d6adb26ebd ↔ Founder 2fa5e046d9413c4b0060b3c4db72365b
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: COO ↔ CEO
#   Tech (samples): Swift, Node.js ↔ Firebase, PostgreSQL
#   Strengths (samples): User empathy, Communication skills ↔ Strong leadership, Communication skills
# Pair: Founder 0a5e3dd8489fe67485ddb7d6adb26ebd ↔ Founder 532f0eaeccfd3cfc16c3f19c01986d37
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: COO ↔ CEO
#   Tech (samples): Swift, Node.js ↔ PostgreSQL, Kubernetes, Docker
#   Strengths (samples): User empathy, Communication skills ↔ Technical depth, Team-building
# Pair: Founder 0a5e3dd8489fe67485ddb7d6adb26ebd ↔ Founder 4f26f7cc49a287a6c05379c899640e66
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: COO ↔ CEO
#   Tech (samples): Swift, Node.js ↔ Unity, C#, JavaScript
#   Strengths (samples): User empathy, Communication skills ↔ User empathy, Analytical problem-solving
# Pair: Founder 0a5e3dd8489fe67485ddb7d6adb26ebd ↔ Founder 5abd4f7ec9779bbd8a961a4aab26b4b1
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: COO ↔ CEO
#   Tech (samples): Swift, Node.js ↔ Webflow, Notion, Bubble
#   Strengths (samples): User empathy, Communication skills ↔ Strategic thinking, Strong leadership
# Pair: Founder 0a5e3dd8489fe67485ddb7d6adb26ebd ↔ Founder 9c16cf2b40aaf1a2b0b535d80f041eb6
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: COO ↔ CTO
#   Tech (samples): Swift, Node.js ↔ AWS, Notion
#   Strengths (samples): User empathy, Communication skills ↔ Strong leadership, Ability to learn quickly
# Cluster 4 - Top Complementary Pairs
# Pair: Founder 024610702baf540af5637873cd1534e9 ↔ Founder 00b74e27ad1cbb2ded8e907fcc49eaaf
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: COO ↔ CEO
#   Tech (samples): Figma, Swift, Notion ↔ Tableau, Bubble
#   Strengths (samples): High ownership, Resilience ↔ Strategic thinking, User empathy
# Pair: Founder 024610702baf540af5637873cd1534e9 ↔ Founder 59ac56fc75373a1228759057df2aa401
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: COO ↔ CPO
#   Tech (samples): Figma, Swift, Notion ↔ Django, Excel
#   Strengths (samples): High ownership, Resilience ↔ Scrappiness, Fast execution
# Pair: Founder 024610702baf540af5637873cd1534e9 ↔ Founder 8077faeaa4104af4f88db4c660e90371
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: COO ↔ CPO
#   Tech (samples): Figma, Swift, Notion ↔ Bubble, Tableau, PostgreSQL
#   Strengths (samples): High ownership, Resilience ↔ Scrappiness, Team-building
# Pair: Founder 024610702baf540af5637873cd1534e9 ↔ Founder b4e6d6a79b772f28ef4ee5a18da94a47
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: COO ↔ CPO
#   Tech (samples): Figma, Swift, Notion ↔ Webflow, Bubble, Django
#   Strengths (samples): High ownership, Resilience ↔ Creativity and vision, Fast execution
# Pair: Founder 024610702baf540af5637873cd1534e9 ↔ Founder 3b56a7c20ee07e6c472f3b021e76e244
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: COO ↔ CEO
#   Tech (samples): Figma, Swift, Notion ↔ MongoDB, PostgreSQL, Python
#   Strengths (samples): High ownership, Resilience ↔ Technical depth, Analytical problem-solving
# Cluster 5 - Top Complementary Pairs
# Pair: Founder 23dbb328ffd9e2fed0e012b922b7f6b2 ↔ Founder 4245f5c0db08dd6d55acf3f7ca17b736
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: CTO ↔ CEO
#   Tech (samples): Docker, Bubble, Excel ↔ Django, Webflow, Swift
#   Strengths (samples): High ownership, Ability to learn quickly ↔ Fast execution, Team-building
# Pair: Founder 23dbb328ffd9e2fed0e012b922b7f6b2 ↔ Founder 64762212f3f8897c359f19cb3012860d
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: CTO ↔ CPO
#   Tech (samples): Docker, Bubble, Excel ↔ Webflow, MongoDB, Python
#   Strengths (samples): High ownership, Ability to learn quickly ↔ Analytical problem-solving, Technical depth
# Pair: Founder 23dbb328ffd9e2fed0e012b922b7f6b2 ↔ Founder 837357a86c027d481d25d201945de076
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: CTO ↔ CEO
#   Tech (samples): Docker, Bubble, Excel ↔ Figma, PostgreSQL, Notion
#   Strengths (samples): High ownership, Ability to learn quickly ↔ Strategic thinking, High ownership
# Pair: Founder 23dbb328ffd9e2fed0e012b922b7f6b2 ↔ Founder b4be096eaaf8ca70dc4d22e31f6b7e44
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: CTO ↔ CPO
#   Tech (samples): Docker, Bubble, Excel ↔ MongoDB, Kubernetes, Node.js
#   Strengths (samples): High ownership, Ability to learn quickly ↔ User empathy, Team-building
# Pair: Founder 23dbb328ffd9e2fed0e012b922b7f6b2 ↔ Founder 2a589b48b66eed314ea98672852d33de
#   Complementarity Score: 0.850 | RoleDiff: 1.0 | TechDiv: 1.00 | S↔W: 0.00
#   Roles: CTO ↔ CEO
#   Tech (samples): Docker, Bubble, Excel ↔ React, Python
#   Strengths (samples): High ownership, Ability to learn quickly ↔ Communication skills, Fast execution
# ================================================================================
